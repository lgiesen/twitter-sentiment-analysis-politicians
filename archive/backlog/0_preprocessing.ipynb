# %%
# TODO: filter by date?; check data quality (if really from city)
# TODO: filter out retweets and potential spam
# in the London data set until April 2019 are tweets from Rotterdam and Amsterdam, so you can use country_code = 'GB' to filter the tweets.
# TODO: check data quality (same column names and tables)
# TODO: Birmingham does not have data before August 2018; the others do
# TODO: not only filter by name of president, but also by keywords; take out the %, because it might include irrelevant results

# %%
import pandas as pd
import os
import time
import sqlite3
from sqlite3 import Error
root = '/Volumes/Festplatte/data-UA/'
# month_path = 'NYC/2018/month_2018_08.db'
president = 'trump'

# %%
cities = ['Birmingham', 'LA', 'London', 'NYC']
years = [str(year) for year in range(2018, 2023)]
# ['2018', '2019', '2020', '2021', '2022']

# %%
def get_files(dir):
    """ get all files from a directory 
    that do not start with a '.'
    :param dir: String
    :return: List of Strings
    """
    return sorted([s for s in os.listdir(dir) if not s.startswith('.')])

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn

# %%
def db_select(conn, table, limit, select = '*', where = 'True'):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute(f'SELECT {select} FROM {table} WHERE {where} LIMIT {limit}')

    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
def create_dataset(conn, month_path, leader_hashtags):
    """ create a dataset based on a database connection to the SQLite database
    :param conn: database connection
    :param month_path: String
    :return: DataFrame
    """
    # join sentiment and tweet table
    # only select english tweets
    data_en_keywords = pd.read_sql_query(
        f"""
        SELECT * 
        FROM tweets 
        INNER JOIN sentiment 
        USING (item_number) 
        WHERE (
            lang == 'en'
            AND
            text LIKE '%{president}%'
        );
        """, 
        conn)
    # alternatively: # cur.execute('SQL STATEMENT')
    # now the compounded sentiment value should be a column as well in the cursor
    assert 'Compound' in data_en_keywords.columns
    
    hashtags = pd.read_sql_query(f'SELECT DISTINCT item_number FROM hashtags WHERE text IN {leader_hashtags}', conn)
    # posts that are not present in the current data_en_keywords that has a relevant hashtag is now added to the data
    newly_relevant_hashtags = list(set(hashtags['item_number']) - set(data_en_keywords['item_number']))
    print(f'{len(newly_relevant_hashtags)} posts are relevant because of hashtags, which were not present in the dataset before.')

    tweets_by_hashtags = pd.read_sql_query(f"""
                                        SELECT * 
                                        FROM tweets INNER JOIN sentiment 
                                        USING (item_number) 
                                        WHERE (
                                            lang == 'en' 
                                            AND 
                                            item_number IN {str(tuple(newly_relevant_hashtags)).replace(',)',')')}
                                        )""", conn)
    
    print(f'There are {tweets_by_hashtags.shape[0]} tweets which are in english and are relevant by using the hashtag')
    # concat the tweets from before with the relevant hashtag-tweets
    data_en_keywords_hashtags = pd.concat([data_en_keywords, tweets_by_hashtags], axis=0)
    return data_en_keywords_hashtags

# %%
boris_johnson_hashtags = ('BorisJohnson', 'UKPrimeMinister', 'ToryLeader', 'Boris')
donald_trump_hashtags = ('DonaldTrump', 'Trump2024', 'MakeAmericaGreatAgain', 'Trump')

# %%
data_path = root + 'data/'
# make directory for relevant data
if not os.path.exists(data_path):
    os.mkdir(data_path)
    os.mkdir(data_path+'trump')
    os.mkdir(data_path+'johnson')

# %% [markdown]
# The files `LA/2018/month_2018_04.db` and `NYC/2020/month_2020_01_RADIUS.db` were deleted because they were empty or did not conform the data format of the other tables

# %%
# %%time
# check how long the loop will take
total_iterations = len(cities) * len(years) * 12  # assuming 12 months per year
completed_iterations = 0
start_time = time.time()

for city in cities:
    for year in years:
        for month in get_files(f'{root}{city}/{year}/'):
            iteration_start_time = time.time()
            month_only = month[-5:-3]
            print(f'{city} - {year} - {month_only}')
            # check if file exists
            month_path = f'{root}{city}/{year}/{month}'
            assert os.path.exists(month_path)
            # create connection
            conn = create_connection(month_path)
            month_dataset = create_dataset(conn, month_path, leader_hashtags=donald_trump_hashtags)
            print(f'The shape of the preprocessed data is: {month_dataset.shape}')
            # save dataset
            month_dataset_path = f'{data_path}{president}/{city}-{year}-{month_only}.pkl'
            month_dataset.to_pickle(month_dataset_path)
            # close the connection
            conn.close()


            completed_iterations += 1
            average_time_per_iteration = (time.time() - start_time) / completed_iterations
            estimated_total_time = average_time_per_iteration * total_iterations
            estimated_time_remaining = estimated_total_time - (time.time() - start_time)
            print(f'Estimated time remaining: {estimated_time_remaining // 60} minutes, {estimated_time_remaining % 60:.2f} seconds')
            print('\n')
# Out:
# Birmingham - 2018 - 08
# 7 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (627, 17)
# Estimated time remaining: 18.0 minutes, 28.10 seconds
#
#
# Birmingham - 2018 - 09
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (618, 17)
# Estimated time remaining: 17.0 minutes, 34.22 seconds
#
#
# Birmingham - 2018 - 10
# 7 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (595, 17)
# Estimated time remaining: 17.0 minutes, 49.17 seconds
#
#
# Birmingham - 2018 - 11
# 4 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (878, 17)
# Estimated time remaining: 17.0 minutes, 34.46 seconds
#
#
# Birmingham - 2018 - 12
# 7 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (811, 17)
# Estimated time remaining: 17.0 minutes, 34.72 seconds
#
#
# Birmingham - 2019 - 01
# 3 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (853, 17)
# Estimated time remaining: 17.0 minutes, 24.65 seconds
#
#
# Birmingham - 2019 - 02
# 8 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (548, 17)
# Estimated time remaining: 17.0 minutes, 9.93 seconds
#
#
# Birmingham - 2019 - 03
# 4 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (474, 17)
# Estimated time remaining: 16.0 minutes, 52.83 seconds
#
#
# Birmingham - 2019 - 04
# 3 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (396, 17)
# Estimated time remaining: 16.0 minutes, 42.91 seconds
#
#
# Birmingham - 2019 - 05
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (720, 17)
# Estimated time remaining: 16.0 minutes, 42.62 seconds
#
#
# Birmingham - 2019 - 06
# 4 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1661, 17)
# Estimated time remaining: 16.0 minutes, 31.64 seconds
#
#
# Birmingham - 2019 - 07
# 4 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1594, 17)
# Estimated time remaining: 16.0 minutes, 23.08 seconds
#
#
# Birmingham - 2019 - 08
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (649, 17)
# Estimated time remaining: 16.0 minutes, 9.31 seconds
#
#
# Birmingham - 2019 - 09
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (504, 17)
# Estimated time remaining: 15.0 minutes, 59.81 seconds
#
#
# Birmingham - 2019 - 10
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (874, 17)
# Estimated time remaining: 15.0 minutes, 50.88 seconds
#
#
# Birmingham - 2019 - 11
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (380, 17)
# Estimated time remaining: 15.0 minutes, 45.00 seconds
#
#
# Birmingham - 2019 - 12
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (544, 17)
# Estimated time remaining: 15.0 minutes, 36.56 seconds
#
#
# Birmingham - 2020 - 01
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (729, 17)
# Estimated time remaining: 15.0 minutes, 28.14 seconds
#
#
# Birmingham - 2020 - 02
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (425, 17)
# Estimated time remaining: 15.0 minutes, 15.14 seconds
#
#
# Birmingham - 2020 - 03
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (510, 17)
# Estimated time remaining: 15.0 minutes, 12.79 seconds
#
#
# Birmingham - 2020 - 04
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (828, 17)
# Estimated time remaining: 15.0 minutes, 15.31 seconds
#
#
# Birmingham - 2020 - 05
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (803, 17)
# Estimated time remaining: 15.0 minutes, 12.25 seconds
#
#
# Birmingham - 2020 - 06
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1042, 17)
# Estimated time remaining: 15.0 minutes, 4.51 seconds
#
#
# Birmingham - 2020 - 07
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (417, 17)
# Estimated time remaining: 14.0 minutes, 56.24 seconds
#
#
# Birmingham - 2020 - 08
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (475, 17)
# Estimated time remaining: 14.0 minutes, 43.48 seconds
#
#
# Birmingham - 2020 - 09
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (478, 17)
# Estimated time remaining: 14.0 minutes, 41.07 seconds
#
#
# Birmingham - 2020 - 10
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1034, 17)
# Estimated time remaining: 14.0 minutes, 36.13 seconds
#
#
# Birmingham - 2020 - 11
# 4 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2818, 17)
# Estimated time remaining: 14.0 minutes, 25.67 seconds
#
#
# Birmingham - 2020 - 12
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (711, 17)
# Estimated time remaining: 14.0 minutes, 14.58 seconds
#
#
# Birmingham - 2021 - 01
# 3 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1476, 17)
# Estimated time remaining: 14.0 minutes, 4.60 seconds
#
#
# Birmingham - 2021 - 02
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (257, 17)
# Estimated time remaining: 13.0 minutes, 51.35 seconds
#
#
# Birmingham - 2021 - 03
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (129, 17)
# Estimated time remaining: 13.0 minutes, 39.33 seconds
#
#
# Birmingham - 2021 - 04
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (139, 17)
# Estimated time remaining: 13.0 minutes, 26.33 seconds
#
#
# Birmingham - 2021 - 05
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (138, 17)
# Estimated time remaining: 13.0 minutes, 13.78 seconds
#
#
# Birmingham - 2021 - 06
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (141, 17)
# Estimated time remaining: 13.0 minutes, 1.55 seconds
#
#
# Birmingham - 2021 - 07
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (126, 17)
# Estimated time remaining: 12.0 minutes, 50.53 seconds
#
#
# Birmingham - 2021 - 08
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (163, 17)
# Estimated time remaining: 12.0 minutes, 39.69 seconds
#
#
# Birmingham - 2021 - 09
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (104, 17)
# Estimated time remaining: 12.0 minutes, 29.53 seconds
#
#
# Birmingham - 2021 - 10
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (156, 17)
# Estimated time remaining: 12.0 minutes, 20.12 seconds
#
#
# Birmingham - 2021 - 11
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (70, 17)
# Estimated time remaining: 12.0 minutes, 10.00 seconds
#
#
# Birmingham - 2021 - 12
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (156, 17)
# Estimated time remaining: 12.0 minutes, 1.32 seconds
#
#
# Birmingham - 2022 - 01
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (145, 17)
# Estimated time remaining: 11.0 minutes, 50.03 seconds
#
#
# Birmingham - 2022 - 02
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (97, 17)
# Estimated time remaining: 11.0 minutes, 38.22 seconds
#
#
# Birmingham - 2022 - 03
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (100, 17)
# Estimated time remaining: 11.0 minutes, 28.91 seconds
#
#
# Birmingham - 2022 - 04
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (121, 17)
# Estimated time remaining: 11.0 minutes, 21.34 seconds
#
#
# Birmingham - 2022 - 05
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (79, 17)
# Estimated time remaining: 11.0 minutes, 14.90 seconds
#
#
# Birmingham - 2022 - 06
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (165, 17)
# Estimated time remaining: 11.0 minutes, 8.29 seconds
#
#
# LA - 2018 - 08
# 39 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 8 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (26589, 17)
# Estimated time remaining: 14.0 minutes, 0.49 seconds
#
#
# LA - 2018 - 09
# 22 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 7 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (21394, 17)
# Estimated time remaining: 16.0 minutes, 32.87 seconds
#
#
# LA - 2018 - 10
# 22 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 5 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (23816, 17)
# Estimated time remaining: 19.0 minutes, 10.10 seconds
#
#
# LA - 2018 - 11
# 15 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (23718, 17)
# Estimated time remaining: 22.0 minutes, 11.53 seconds
#
#
# LA - 2018 - 12
# 11 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (23547, 17)
# Estimated time remaining: 27.0 minutes, 4.27 seconds
#
#
# LA - 2019 - 01
# 16 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (29501, 17)
# Estimated time remaining: 31.0 minutes, 54.35 seconds
#
#
# LA - 2019 - 02
# 9 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (20604, 17)
# Estimated time remaining: 36.0 minutes, 50.25 seconds
#
#
# LA - 2019 - 03
# 9 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (16160, 17)
# Estimated time remaining: 40.0 minutes, 44.54 seconds
#
#
# LA - 2019 - 04
# 7 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (14965, 17)
# Estimated time remaining: 42.0 minutes, 37.21 seconds
#
#
# LA - 2019 - 05
# 12 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (15291, 17)
# Estimated time remaining: 46.0 minutes, 50.48 seconds
#
#
# LA - 2019 - 06
# 21 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (17620, 17)
# Estimated time remaining: 51.0 minutes, 4.27 seconds
#
#
# LA - 2019 - 07
# 27 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (21657, 17)
# Estimated time remaining: 55.0 minutes, 30.40 seconds
#
#
# LA - 2019 - 08
# 10 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (19167, 17)
# Estimated time remaining: 59.0 minutes, 13.29 seconds
#
#
# LA - 2019 - 09
# 13 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (16689, 17)
# Estimated time remaining: 62.0 minutes, 50.34 seconds
#
#
# LA - 2019 - 10
# 9 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (23551, 17)
# Estimated time remaining: 66.0 minutes, 55.53 seconds
#
#
# LA - 2019 - 11
# 15 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (17296, 17)
# Estimated time remaining: 70.0 minutes, 3.02 seconds
#
#
# LA - 2019 - 12
# 18 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (17165, 17)
# Estimated time remaining: 73.0 minutes, 36.03 seconds
#
#
# LA - 2020 - 01
# 19 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (19105, 17)
# Estimated time remaining: 77.0 minutes, 2.50 seconds
#
#
# LA - 2020 - 02
# 14 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (18449, 17)
# Estimated time remaining: 80.0 minutes, 3.58 seconds
#
#
# LA - 2020 - 03
# 37 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (28449, 17)
# Estimated time remaining: 82.0 minutes, 19.83 seconds
#
#
# LA - 2020 - 04
# 29 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (25257, 17)
# Estimated time remaining: 82.0 minutes, 22.52 seconds
#
#
# LA - 2020 - 05
# 48 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (25014, 17)
# Estimated time remaining: 81.0 minutes, 56.54 seconds
#
#
# LA - 2020 - 06
# 71 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (32697, 17)
# Estimated time remaining: 81.0 minutes, 19.79 seconds
#
#
# LA - 2020 - 07
# 50 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (24558, 17)
# Estimated time remaining: 80.0 minutes, 41.58 seconds
#
#
# LA - 2020 - 08
# 28 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 4 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (27554, 17)
# Estimated time remaining: 80.0 minutes, 5.90 seconds
#
#
# LA - 2020 - 09
# 33 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (29333, 17)
# Estimated time remaining: 79.0 minutes, 31.78 seconds
#
#
# LA - 2020 - 10
# 57 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (35786, 17)
# Estimated time remaining: 79.0 minutes, 4.38 seconds
#
#
# LA - 2020 - 11
# 44 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 3 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (38654, 17)
# Estimated time remaining: 78.0 minutes, 24.86 seconds
#
#
# LA - 2020 - 12
# 19 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (15569, 17)
# Estimated time remaining: 77.0 minutes, 34.30 seconds
#
#
# LA - 2021 - 01
# 63 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (22878, 17)
# Estimated time remaining: 76.0 minutes, 48.85 seconds
#
#
# LA - 2021 - 02
# 15 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (5936, 17)
# Estimated time remaining: 75.0 minutes, 53.73 seconds
#
#
# LA - 2021 - 03
# 5 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3094, 17)
# Estimated time remaining: 74.0 minutes, 56.57 seconds
#
#
# LA - 2021 - 04
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2046, 17)
# Estimated time remaining: 74.0 minutes, 13.04 seconds
#
#
# LA - 2021 - 05
# 9 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2346, 17)
# Estimated time remaining: 73.0 minutes, 19.61 seconds
#
#
# LA - 2021 - 06
# 10 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2338, 17)
# Estimated time remaining: 72.0 minutes, 25.65 seconds
#
#
# LA - 2021 - 07
# 6 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2739, 17)
# Estimated time remaining: 71.0 minutes, 44.55 seconds
#
#
# LA - 2021 - 08
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3281, 17)
# Estimated time remaining: 70.0 minutes, 51.78 seconds
#
#
# LA - 2021 - 09
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2755, 17)
# Estimated time remaining: 70.0 minutes, 11.96 seconds
#
#
# LA - 2021 - 10
# 9 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2498, 17)
# Estimated time remaining: 69.0 minutes, 26.49 seconds
#
#
# LA - 2021 - 11
# 5 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2150, 17)
# Estimated time remaining: 68.0 minutes, 35.32 seconds
#
#
# LA - 2021 - 12
# 7 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2425, 17)
# Estimated time remaining: 67.0 minutes, 44.27 seconds
#
#
# LA - 2022 - 01
# 6 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2157, 17)
# Estimated time remaining: 67.0 minutes, 0.20 seconds
#
#
# LA - 2022 - 02
# 8 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2549, 17)
# Estimated time remaining: 66.0 minutes, 5.48 seconds
#
#
# LA - 2022 - 03
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2739, 17)
# Estimated time remaining: 65.0 minutes, 15.80 seconds
#
#
# LA - 2022 - 04
# 10 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2271, 17)
# Estimated time remaining: 64.0 minutes, 32.35 seconds
#
#
# LA - 2022 - 05
# 8 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2862, 17)
# Estimated time remaining: 63.0 minutes, 46.32 seconds
#
#
# LA - 2022 - 06
# 9 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (6179, 17)
# Estimated time remaining: 63.0 minutes, 16.53 seconds
#
#
# London - 2018 - 08
# 6 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (5278, 17)
# Estimated time remaining: 62.0 minutes, 40.57 seconds
#
#
# London - 2018 - 09
# 11 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4307, 17)
# Estimated time remaining: 62.0 minutes, 14.87 seconds
#
#
# London - 2018 - 10
# 15 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4510, 17)
# Estimated time remaining: 61.0 minutes, 46.80 seconds
#
#
# London - 2018 - 11
# 17 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (5395, 17)
# Estimated time remaining: 61.0 minutes, 18.24 seconds
#
#
# London - 2018 - 12
# 12 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4679, 17)
# Estimated time remaining: 60.0 minutes, 47.32 seconds
#
#
# London - 2019 - 01
# 8 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (5778, 17)
# Estimated time remaining: 60.0 minutes, 14.86 seconds
#
#
# London - 2019 - 02
# 6 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4464, 17)
# Estimated time remaining: 59.0 minutes, 39.49 seconds
#
#
# London - 2019 - 03
# 7 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4063, 17)
# Estimated time remaining: 59.0 minutes, 4.74 seconds
#
#
# London - 2019 - 04
# 11 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3396, 17)
# Estimated time remaining: 58.0 minutes, 34.93 seconds
#
#
# London - 2019 - 05
# 12 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3685, 17)
# Estimated time remaining: 58.0 minutes, 2.81 seconds
#
#
# London - 2019 - 06
# 40 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (7993, 17)
# Estimated time remaining: 57.0 minutes, 33.37 seconds
#
#
# London - 2019 - 07
# 11 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (6130, 17)
# Estimated time remaining: 57.0 minutes, 6.63 seconds
#
#
# London - 2019 - 08
# 17 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4205, 17)
# Estimated time remaining: 56.0 minutes, 33.44 seconds
#
#
# London - 2019 - 09
# 11 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3276, 17)
# Estimated time remaining: 56.0 minutes, 1.88 seconds
#
#
# London - 2019 - 10
# 10 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4472, 17)
# Estimated time remaining: 55.0 minutes, 37.65 seconds
#
#
# London - 2019 - 11
# 11 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3797, 17)
# Estimated time remaining: 55.0 minutes, 12.57 seconds
#
#
# London - 2019 - 12
# 10 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3984, 17)
# Estimated time remaining: 54.0 minutes, 43.56 seconds
#
#
# London - 2020 - 01
# 15 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4451, 17)
# Estimated time remaining: 54.0 minutes, 14.27 seconds
#
#
# London - 2020 - 02
# 47 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3285, 17)
# Estimated time remaining: 53.0 minutes, 42.31 seconds
#
#
# London - 2020 - 03
# 10 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4512, 17)
# Estimated time remaining: 53.0 minutes, 16.14 seconds
#
#
# London - 2020 - 04
# 20 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4880, 17)
# Estimated time remaining: 52.0 minutes, 47.11 seconds
#
#
# London - 2020 - 05
# 9 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4899, 17)
# Estimated time remaining: 52.0 minutes, 19.00 seconds
#
#
# London - 2020 - 06
# 24 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (5985, 17)
# Estimated time remaining: 51.0 minutes, 48.91 seconds
#
#
# London - 2020 - 07
# 17 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4124, 17)
# Estimated time remaining: 51.0 minutes, 17.80 seconds
#
#
# London - 2020 - 08
# 30 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4703, 17)
# Estimated time remaining: 50.0 minutes, 45.62 seconds
#
#
# London - 2020 - 09
# 19 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4783, 17)
# Estimated time remaining: 50.0 minutes, 13.86 seconds
#
#
# London - 2020 - 10
# 43 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (7208, 17)
# Estimated time remaining: 49.0 minutes, 43.01 seconds
#
#
# London - 2020 - 11
# 56 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (15286, 17)
# Estimated time remaining: 49.0 minutes, 11.69 seconds
#
#
# London - 2020 - 12
# 4 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4239, 17)
# Estimated time remaining: 48.0 minutes, 37.83 seconds
#
#
# London - 2021 - 01
# 43 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (8439, 17)
# Estimated time remaining: 48.0 minutes, 11.54 seconds
#
#
# London - 2021 - 02
# 16 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1711, 17)
# Estimated time remaining: 47.0 minutes, 40.79 seconds
#
#
# London - 2021 - 03
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (925, 17)
# Estimated time remaining: 47.0 minutes, 7.52 seconds
#
#
# London - 2021 - 04
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (554, 17)
# Estimated time remaining: 46.0 minutes, 33.07 seconds
#
#
# London - 2021 - 05
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (862, 17)
# Estimated time remaining: 45.0 minutes, 57.72 seconds
#
#
# London - 2021 - 06
# 5 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (908, 17)
# Estimated time remaining: 45.0 minutes, 23.31 seconds
#
#
# London - 2021 - 07
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (817, 17)
# Estimated time remaining: 44.0 minutes, 49.64 seconds
#
#
# London - 2021 - 08
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1159, 17)
# Estimated time remaining: 44.0 minutes, 15.72 seconds
#
#
# London - 2021 - 09
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (644, 17)
# Estimated time remaining: 43.0 minutes, 41.09 seconds
#
#
# London - 2021 - 10
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (608, 17)
# Estimated time remaining: 43.0 minutes, 6.91 seconds
#
#
# London - 2021 - 11
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (633, 17)
# Estimated time remaining: 42.0 minutes, 34.10 seconds
#
#
# London - 2021 - 12
# 3 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (583, 17)
# Estimated time remaining: 42.0 minutes, 1.16 seconds
#
#
# London - 2022 - 01
# 5 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (451, 17)
# Estimated time remaining: 41.0 minutes, 26.40 seconds
#
#
# London - 2022 - 02
# 5 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (590, 17)
# Estimated time remaining: 40.0 minutes, 51.50 seconds
#
#
# London - 2022 - 03
# 0 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (694, 17)
# Estimated time remaining: 40.0 minutes, 17.87 seconds
#
#
# London - 2022 - 04
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (598, 17)
# Estimated time remaining: 39.0 minutes, 45.66 seconds
#
#
# London - 2022 - 05
# 1 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (497, 17)
# Estimated time remaining: 39.0 minutes, 14.61 seconds
#
#
# London - 2022 - 06
# 3 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (590, 17)
# Estimated time remaining: 38.0 minutes, 43.75 seconds
#
#
# London - 2022 - 07
# 2 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (756, 17)
# Estimated time remaining: 38.0 minutes, 13.97 seconds
#
#
# NYC - 2018 - 01
# 73 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 3 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (29036, 17)
# Estimated time remaining: 37.0 minutes, 51.67 seconds
#
#
# NYC - 2018 - 02
# 39 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 5 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (21152, 17)
# Estimated time remaining: 37.0 minutes, 28.09 seconds
#
#
# NYC - 2018 - 03
# 31 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (18778, 17)
# Estimated time remaining: 37.0 minutes, 4.95 seconds
#
#
# NYC - 2018 - 04
# 42 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (19380, 17)
# Estimated time remaining: 36.0 minutes, 40.90 seconds
#
#
# NYC - 2018 - 05
# 54 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (20055, 17)
# Estimated time remaining: 36.0 minutes, 16.34 seconds
#
#
# NYC - 2018 - 06
# 75 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 5 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (27020, 17)
# Estimated time remaining: 35.0 minutes, 53.10 seconds
#
#
# NYC - 2018 - 07
# 56 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 3 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (25416, 17)
# Estimated time remaining: 35.0 minutes, 29.97 seconds
#
#
# NYC - 2018 - 08
# 45 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 13 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (24245, 17)
# Estimated time remaining: 35.0 minutes, 8.25 seconds
#
#
# NYC - 2018 - 09
# 73 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 8 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (21733, 17)
# Estimated time remaining: 34.0 minutes, 46.12 seconds
#
#
# NYC - 2018 - 10
# 60 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 4 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (24212, 17)
# Estimated time remaining: 34.0 minutes, 25.27 seconds
#
#
# NYC - 2018 - 11
# 58 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 5 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (22412, 17)
# Estimated time remaining: 34.0 minutes, 2.37 seconds
#
#
# NYC - 2018 - 12
# 52 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (22419, 17)
# Estimated time remaining: 33.0 minutes, 38.90 seconds
#
#
# NYC - 2019 - 01
# 52 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 5 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (30454, 17)
# Estimated time remaining: 33.0 minutes, 16.03 seconds
#
#
# NYC - 2019 - 02
# 21 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (19951, 17)
# Estimated time remaining: 32.0 minutes, 51.92 seconds
#
#
# NYC - 2019 - 03
# 21 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (16727, 17)
# Estimated time remaining: 32.0 minutes, 26.53 seconds
#
#
# NYC - 2019 - 04
# 16 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (15799, 17)
# Estimated time remaining: 32.0 minutes, 1.51 seconds
#
#
# NYC - 2019 - 05
# 21 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (17003, 17)
# Estimated time remaining: 31.0 minutes, 37.19 seconds
#
#
# NYC - 2019 - 06
# 22 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (15490, 17)
# Estimated time remaining: 31.0 minutes, 13.24 seconds
#
#
# NYC - 2019 - 07
# 100 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (18882, 17)
# Estimated time remaining: 30.0 minutes, 49.07 seconds
#
#
# NYC - 2019 - 08
# 99 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (16653, 17)
# Estimated time remaining: 30.0 minutes, 24.63 seconds
#
#
# NYC - 2019 - 09
# 62 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (14579, 17)
# Estimated time remaining: 30.0 minutes, 1.20 seconds
#
#
# NYC - 2019 - 10
# 60 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (19740, 17)
# Estimated time remaining: 29.0 minutes, 37.65 seconds
#
#
# NYC - 2019 - 11
# 78 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (15173, 17)
# Estimated time remaining: 29.0 minutes, 13.04 seconds
#
#
# NYC - 2019 - 12
# 67 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (15008, 17)
# Estimated time remaining: 30.0 minutes, 30.51 seconds
#
#
# NYC - 2020 - 01
# 64 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 3 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (17943, 17)
# Estimated time remaining: 30.0 minutes, 4.20 seconds
#
#
# NYC - 2020 - 02
# 64 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (17692, 17)
# Estimated time remaining: 29.0 minutes, 39.98 seconds
#
#
# NYC - 2020 - 03
# 58 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (24117, 17)
# Estimated time remaining: 29.0 minutes, 19.65 seconds
#
#
# NYC - 2020 - 04
# 39 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (22100, 17)
# Estimated time remaining: 28.0 minutes, 53.93 seconds
#
#
# NYC - 2020 - 05
# 27 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (20072, 17)
# Estimated time remaining: 28.0 minutes, 27.76 seconds
#
#
# NYC - 2020 - 06
# 194 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (25870, 17)
# Estimated time remaining: 28.0 minutes, 1.61 seconds
#
#
# NYC - 2020 - 07
# 175 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (23399, 17)
# Estimated time remaining: 27.0 minutes, 34.95 seconds
#
#
# NYC - 2020 - 08
# 122 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 3 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (25763, 17)
# Estimated time remaining: 27.0 minutes, 9.94 seconds
#
#
# NYC - 2020 - 09
# 40 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (28307, 17)
# Estimated time remaining: 26.0 minutes, 43.38 seconds
#
#
# NYC - 2020 - 10
# 109 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (32804, 17)
# Estimated time remaining: 26.0 minutes, 17.84 seconds
#
#
# NYC - 2020 - 11
# 144 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (38367, 17)
# Estimated time remaining: 25.0 minutes, 51.35 seconds
#
#
# NYC - 2020 - 12
# 32 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (17399, 17)
# Estimated time remaining: 25.0 minutes, 24.27 seconds
#
#
# NYC - 2021 - 01
# 110 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (22851, 17)
# Estimated time remaining: 24.0 minutes, 57.24 seconds
#
#
# NYC - 2021 - 02
# 42 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (6736, 17)
# Estimated time remaining: 24.0 minutes, 29.14 seconds
#
#
# NYC - 2021 - 03
# 20 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 2 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4187, 17)
# Estimated time remaining: 24.0 minutes, 1.69 seconds
#
#
# NYC - 2021 - 04
# 5 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2534, 17)
# Estimated time remaining: 23.0 minutes, 33.59 seconds
#
#
# NYC - 2021 - 05
# 8 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2889, 17)
# Estimated time remaining: 23.0 minutes, 5.69 seconds
#
#
# NYC - 2021 - 06
# 4 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2619, 17)
# Estimated time remaining: 22.0 minutes, 37.70 seconds
#
#
# NYC - 2021 - 07
# 22 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2889, 17)
# Estimated time remaining: 22.0 minutes, 10.37 seconds
#
#
# NYC - 2021 - 08
# 18 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3351, 17)
# Estimated time remaining: 21.0 minutes, 43.31 seconds
#
#
# NYC - 2021 - 09
# 15 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2341, 17)
# Estimated time remaining: 21.0 minutes, 16.29 seconds
#
#
# NYC - 2021 - 10
# 21 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2058, 17)
# Estimated time remaining: 20.0 minutes, 49.10 seconds
#
#
# NYC - 2021 - 11
# 36 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1926, 17)
# Estimated time remaining: 20.0 minutes, 21.99 seconds
#
#
# NYC - 2021 - 12
# 16 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 4 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2055, 17)
# Estimated time remaining: 19.0 minutes, 55.27 seconds
#
#
# NYC - 2022 - 01
# 56 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (1744, 17)
# Estimated time remaining: 19.0 minutes, 27.82 seconds
#
#
# NYC - 2022 - 02
# 43 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2475, 17)
# Estimated time remaining: 19.0 minutes, 4.57 seconds
#
#
# NYC - 2022 - 03
# 48 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2700, 17)
# Estimated time remaining: 18.0 minutes, 38.67 seconds
#
#
# NYC - 2022 - 04
# 42 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2303, 17)
# Estimated time remaining: 18.0 minutes, 12.08 seconds
#
#
# NYC - 2022 - 05
# 31 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (2644, 17)
# Estimated time remaining: 17.0 minutes, 45.88 seconds
#
#
# NYC - 2022 - 06
# 16 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 0 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (4188, 17)
# Estimated time remaining: 17.0 minutes, 20.17 seconds
#
#
# NYC - 2022 - 07
# 9 posts are relevant because of hashtags, which were not present in the dataset before.
# There are 1 tweets which are in english and are relevant by using the hashtag
# The shape of the preprocessed data is: (3656, 17)
# Estimated time remaining: 16.0 minutes, 54.39 seconds
#
#
# CPU times: user 3min 5s, sys: 3min 2s, total: 6min 7s
# Wall time: 1h 17min 27s

# %%
# TODO: filter out retweets and potential spam | tokenization, lemmatization and stopword removal

# %%
# TODO: vectorization (bag of words or bag-of-ngrams or word2vec)
